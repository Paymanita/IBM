# %%
My Jupyter Notebook on IBM Watson Studio

# %%
Paymaneh Azarm

# %%
Data Scientist
I am interested in data science because I want to learn how to extract meaningful information from data.

# %%
My code in the next cell will print a word.

# %%
print('Hello My Friend!')
# Out:
# Hello My Friend!
